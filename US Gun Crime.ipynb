# %%
import pandas as pd
import numpy as np

#read in csv file
reading_in = pd.read_csv('/Users/neilwatt/Documents/Collaborations/USGunCrime/gunstats.csv', encoding = "ISO-8859-1")


#create dataframe
#I'm only pulling in columns where at more than 10% of values are populated
df = pd.DataFrame(reading_in, columns=["address","congressional_district","latitude","longitude","sources","source_url","incident_characteristics","incident_id","date","state","city_or_county","n_killed","n_injured","incident_url","incident_url_fields_missing"])
df
# Out:
#                                                   address  \
# 0               1506 Versailles Avenue and Coursin Street
# 1                            13500 block of Cerise Avenue
# 2                                   1776 East 28th Street
# 3                        16000 block of East Ithaca Place
# 4                               307 Mourning Dove Terrace
# 5                              6000 block of South Owasso
# 6                                          2806 Long Lane
# 7       LaSalle Street and Martin Luther King Jr. Boul...
# 8                              1100 block of Breton Drive
# 9                            1500 block of W. Fayette St.
# 10                                         1501 Dodds Ave
# 11                    W Florissant Ave and Riverview Blvd
# 12                           1000 block of Flat Town Road
# 13                            2403 Benning Road Northeast
# 14                                   601 West Main Street
# ...

# %%
#check which columns have null values
df.isnull()

#rather than delete all columns with any blanks I went back and changed the data frame
# Out:
#         address  congressional_district  latitude  longitude  sources  \
# 0         False                   False     False      False    False
# 1         False                   False     False      False    False
# 2         False                   False     False      False    False
# 3         False                   False     False      False    False
# 4         False                   False     False      False    False
# 5         False                   False     False      False    False
# 6         False                   False     False      False    False
# 7         False                   False     False      False    False
# 8         False                   False     False      False    False
# 9         False                   False     False      False    False
# 10        False                   False     False      False    False
# 11        False                   False     False      False    False
# ...

# %%
#drop NA rows

df2=df.dropna()
df2

#we go from 239677  to 210479 rows so we retain 87% of the original data
# Out:
#                                                   address  \
# 0               1506 Versailles Avenue and Coursin Street
# 1                            13500 block of Cerise Avenue
# 2                                   1776 East 28th Street
# 3                        16000 block of East Ithaca Place
# 4                               307 Mourning Dove Terrace
# 5                              6000 block of South Owasso
# 6                                          2806 Long Lane
# 7       LaSalle Street and Martin Luther King Jr. Boul...
# 8                              1100 block of Breton Drive
# 9                            1500 block of W. Fayette St.
# 10                                         1501 Dodds Ave
# 11                    W Florissant Ave and Riverview Blvd
# 12                           1000 block of Flat Town Road
# 13                            2403 Benning Road Northeast
# 14                                   601 West Main Street
# ...
